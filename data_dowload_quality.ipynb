# %%
# Importing packages
import requests
import zipfile
import io
import pandas as pd
import os
from inmet_data_functions import download_inmet_data, inmet_data_quality

# %%
# Dowload INMET's data
download_inmet_data(years = range(2000, 2025), path = "https://portal.inmet.gov.br/uploads/dadoshistoricos/", output_path = "DATA")
# Out:
# https://portal.inmet.gov.br/uploads/dadoshistoricos/2000.zip
# Initializing download from 2000
# Stored 5 from a total of 5 files.
# Saved 5 from a total of 5 files.
# Download finished
# https://portal.inmet.gov.br/uploads/dadoshistoricos/2001.zip
# Initializing download from 2001
# Stored 16 from a total of 16 files.
# Saved 16 from a total of 16 files.
# Download finished
# https://portal.inmet.gov.br/uploads/dadoshistoricos/2002.zip
# Initializing download from 2002
# Stored 33 from a total of 33 files.
# Saved 33 from a total of 33 files.
# Download finished
# https://portal.inmet.gov.br/uploads/dadoshistoricos/2003.zip
# Initializing download from 2003
# Stored 55 from a total of 55 files.
# Saved 55 from a total of 55 files.
# Download finished
# https://portal.inmet.gov.br/uploads/dadoshistoricos/2004.zip
# Initializing download from 2004
# Stored 62 from a total of 62 files.
# Saved 62 from a total of 62 files.
# Download finished
# ...

# %%
# Verify data quality evaluating the percentage of missing data
inmet_data_quality(years = range(2000, 2025), path = 'DATA')
# Out:
# DATA//INMET_DATA_2000.csv
# DATA//INMET_DATA_2001.csv
# DATA//INMET_DATA_2002.csv
# DATA//INMET_DATA_2003.csv
# DATA//INMET_DATA_2004.csv
# DATA//INMET_DATA_2005.csv
# DATA//INMET_DATA_2006.csv
# DATA//INMET_DATA_2007.csv
# DATA//INMET_DATA_2008.csv
# DATA//INMET_DATA_2009.csv
# DATA//INMET_DATA_2010.csv
# DATA//INMET_DATA_2011.csv
# DATA//INMET_DATA_2012.csv
# DATA//INMET_DATA_2013.csv
# DATA//INMET_DATA_2014.csv
# DATA//INMET_DATA_2015.csv
# DATA//INMET_DATA_2016.csv
# DATA//INMET_DATA_2017.csv
# DATA//INMET_DATA_2018.csv
# DATA//INMET_DATA_2019.csv
# DATA//INMET_DATA_2020.csv
# DATA//INMET_DATA_2021.csv
# DATA//INMET_DATA_2022.csv
# DATA//INMET_DATA_2023.csv
# DATA//INMET_DATA_2024.csv
# Data quality file saved
